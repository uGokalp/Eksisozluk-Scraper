# %%
# %load_ext autoreload
import requests
from bs4 import BeautifulSoup
from funcs import *

# %%
headers_1 = {"User-Agent": "Mozilla/5.0"}
url = 'https://eksisozluk.com/yngwie-malmsteen-gitar-egitim-videolari--5050154'
end_page = find_end(url)
end_page
# Out:
# 1

# %%
url2 = 'https://eksisozluk.com/gitar-calmanin-artik-luks-bir-hobi-olmasi--6090591'

# %%
ry = requests.get(url2, headers=headers_1)
soupy = BeautifulSoup(ry.content, 'html.parser').find
print(soupy)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="tr">
# <head>
# <!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=edge"><![endif]-->
# <meta charset="utf-8"/>
# <title>gitar çalmanın artık lüks bir hobi olması - ekşi sözlük</title>
# <link href="/odesc.xml" rel="search" title="ekşi sözlük" type="application/opensearchdescription+xml"/>
# <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:400,700,400italic,700italic,600&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
# <link href="/content/css/t1613.css" id="ad-theme" rel="stylesheet" type="text/css">
# <script>
#   dataLayer = [{
#   'elogin': '0',
#   'eloginid':'0',
#   'eauthor': '',
#   'esubdom': 'eksisozluk',
#   'etitle': 'gitar-calmanin-artik-luks-bir-hobi-olmasi',
#   'ecat1': '',
#   'econtentid': '6090591',
#   'epagetype': 'detail',
#   'epublishdate': '',
#   'epublishtime': '',
#   'econtenttype': 'topic',
#   'efiltre': '',
#   'adu': '0',
#   }];
# </script>
# ...
