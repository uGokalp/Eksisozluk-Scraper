# %%
# %load_ext autoreload
# %autoreload 2
# %autoreload 1
from funcs import *
from collections import Counter

# %%
turk_telekom = 'https://eksisozluk.com/turk-telekom--38478'
list_turk, list_date = get_with_method(turk_telekom)
# Out:
#   0%|          | 0/411 [00:00<?, ?it/s]
# This title has 411 pages
# 100%|██████████| 411/411 [09:54<00:00,  1.31s/it]

# %%
print("Length of list_date is", len(list_date))
print("Length of list_turk is", len(list_turk))
# Out:
# Length of list_date is 4104
# Length of list_turk is 4104

# %%
df = pd.DataFrame({'entry': list_turk, 'date': list_date});df
# Out:
#                                                   entry        date
# 0     halkim bir suru ben bunlari nasil duduklerim o...  08.03.2000
# 1              napacagi belli olmayan basketbol takimi.  04.11.2000
# 2     bazen mit gibi calistigini dusundugum ilginc s...  15.02.2001
# 3     data devrelerine yaptigi fahis zamla isp leri ...  09.04.2001
# 4     ozellestirilmesinin cok seyi degistirmeyecegin...  16.04.2001
# 5     ozellestirildiginde herseyin daha da boktan bi...  14.05.2001
# 6     ben: iyi gunler. turk telekom mu?tt: evet buyr...  24.07.2001
# 7                                  (bkz:türk tenekekom)  20.08.2001
# 8                            http://www.telekom.gov.tr/  17.10.2001
# 9     acıbadem'de , avrupa yakasının bile belirli bö...  17.01.2002
# 10                              evde kalmış kız kurusu.  17.01.2002
# 11                         (bkz:turk telekom rezilligi)  23.03.2002
# 12    0822li numaralarda çevrilen numara meşgul olsa...  23.03.2002
# ...

# %%
from PIL import Image

# %%
Counter(flattened)
# Out:
# Counter({'halkim': 1,
#          'bir': 5941,
#          'suru': 4,
#          'ben': 961,
#          'bunlari': 6,
#          'nasil': 32,
#          'duduklerim': 1,
#          'oy': 4,
#          'diye': 1036,
#          'taklalar': 2,
#          'atan': 22,
#          'kurum': 371,
#          'napacagi': 1,
#          'belli': 66,
#          'olmayan': 156,
#          'basketbol': 35,
#          'takimi': 4,
#          'bazen': 32,
#          'mit': 1,
#          'gibi': 953,
#          'calistigini': 2,
#          'dusundugum': 5,
#          'ilginc': 2,
#          'sirketzamaninda': 1,
#          'irc': 2,
#          'de': 2169,
#          'rastladigim': 1,
#          'birisi': 38,
#          'muhabbet': 11,
#          'arasinda': 8,
#          'bana': 621,
#          'turk': 168,
#          'nokta': 21,
#          'net': 103,
#          'ten': 10,
#          'baskasinin': 2,
#          'kredi': 56,
#          'karti': 3,
#          'ile': 934,
#          'yaptigim': 3,
# ...

# %%
plot_wordcloud(text=df.entry,title='Turk Telekom',names='turk_telekom')

# %%
Image.open('wordcloud/turk_telekom.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x400 at 0x16658CBA8>
